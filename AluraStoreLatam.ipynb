# %% [markdown]
# <a href="https://colab.research.google.com/github/Nancy-Velazquez/AluraStoreLatam/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# ## **Exploración inicial de los datos**

# %% [markdown]
# Exploración de la tienda 1

# %%
tienda.sample(5)
# Out:
#                Producto Categoría del Producto    Precio  Costo de envío  \
# 427      Mesa de centro                Muebles  194100.0         10700.0
# 646   Asistente virtual           Electrónicos  206400.0         11700.0
# 1447          Bicicleta   Deportes y diversión  573300.0         31000.0
# 1391        Muñeca bebé               Juguetes   44000.0          2700.0
# 1744             Sillón                Muebles  290200.0         15800.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 427       02/01/2022    Rafael Acosta        Medellín             5
# 646       12/07/2021    Maria Alfonso            Cali             5
# 1447      25/02/2022    Lucas Olivera          Bogotá             5
# 1391      03/04/2021  Izabela de León        Medellín             5
# 1744      22/08/2022  Izabela de León     Bucaramanga             5
#
#           Método de pago  Cantidad de cuotas      lat       lon
# ...

# %%
tienda.shape
# Out:
# (2359, 12)

# %%
tienda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %% [markdown]
# Exploración de la tienda 2

# %%
tienda2.sample(5)
# Out:
#                      Producto Categoría del Producto     Precio  \
# 728                 Iphone 15           Electrónicos  1868700.0
# 672   Dashboards con Power BI                 Libros    34600.0
# 942        Cuerda para saltar   Deportes y diversión    13500.0
# 461           Mesa de comedor                Muebles   227700.0
# 1251             Refrigerador      Electrodomésticos  2185600.0
#
#       Costo de envío Fecha de Compra        Vendedor Lugar de Compra  \
# 728         101900.0      11/01/2022  Juan Fernandez           Pasto
# 672              0.0      06/02/2022   Maria Alfonso     Bucaramanga
# 942            900.0      26/04/2021   Lucas Olivera       Cartagena
# 461          12800.0      02/01/2023   Felipe Santos          Bogotá
# 1251        114600.0      07/12/2020   Juliana Costa          Bogotá
#
#       Calificación      Método de pago  Cantidad de cuotas       lat       lon
# 728              5  Tarjeta de crédito                   3   1.21361 -77.28111
# ...

# %%
tienda2.shape
# Out:
# (2359, 12)

# %%
tienda2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %% [markdown]
# Exploración de la tienda 3

# %%
tienda3.sample(5)
# Out:
#                          Producto Categoría del Producto    Precio  \
# 74             Cuerda para saltar   Deportes y diversión    7900.0
# 1552                    Cama king                Muebles  823400.0
# 2086            Asistente virtual           Electrónicos  115500.0
# 2052  Ciencia de datos con Python                 Libros   49300.0
# 75                         Estufa      Electrodomésticos  484500.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 74               0.0      28/02/2023    Rafael Acosta          Bogotá
# 1552         49900.0      30/11/2020   Santiago Silva          Bogotá
# 2086          6500.0      28/08/2021    Juliana Costa    Barranquilla
# 2052          6000.0      03/08/2021  Ángel Rodriguez        Medellín
# 75           26000.0      28/11/2021    Juliana Costa          Bogotá
#
#       Calificación      Método de pago  Cantidad de cuotas       lat       lon
# ...

# %%
tienda3.shape
# Out:
# (2359, 12)

# %%
tienda3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB

# %% [markdown]
# Exploración de la tienda 4

# %%
tienda4.sample(5)
# Out:
#                      Producto   Categoría del Producto    Precio  \
# 2253  Dashboards con Power BI                   Libros   28500.0
# 848                Cubertería  Artículos para el hogar   59900.0
# 1020          Sofá reclinable                  Muebles  748500.0
# 768              Set de ollas  Artículos para el hogar   92200.0
# 726   Dashboards con Power BI                   Libros   36900.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 2253          7200.0      17/05/2022    Camila Rivera          Bogotá
# 848           3400.0      08/07/2022   Santiago Silva          Bogotá
# 1020         40300.0      21/03/2021      Pedro Gomez         Pereira
# 768           5300.0      24/08/2022  Izabela de León        Medellín
# 726              0.0      23/09/2020  Ángel Rodriguez          Bogotá
#
#       Calificación      Método de pago  Cantidad de cuotas      lat       lon
# ...

# %%
tienda4.shape
# Out:
# (2358, 12)

# %%
tienda4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2358 non-null   object
#  1   Categoría del Producto  2358 non-null   object
#  2   Precio                  2358 non-null   float64
#  3   Costo de envío          2358 non-null   float64
#  4   Fecha de Compra         2358 non-null   object
#  5   Vendedor                2358 non-null   object
#  6   Lugar de Compra         2358 non-null   object
#  7   Calificación            2358 non-null   int64
#  8   Método de pago          2358 non-null   object
#  9   Cantidad de cuotas      2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.2+ KB

# %% [markdown]
# #1. Análisis de facturación

# %%
ingresos_tienda1 = tienda['Precio'].sum()
ingresos_tienda2 = tienda2['Precio'].sum()
ingresos_tienda3 = tienda3['Precio'].sum()
ingresos_tienda4 = tienda4['Precio'].sum()
print(f"Ingreso Total Tienda 1: ${ingresos_tienda1:,.2f}")
print(f"Ingreso Total Tienda 2: ${ingresos_tienda2:,.2f}")
print(f"Ingreso Total Tienda 3: ${ingresos_tienda3:,.2f}")
print(f"Ingreso Total Tienda 4: ${ingresos_tienda4:,.2f}")
# Out:
# Ingreso Total Tienda 1: $1,150,880,400.00
# Ingreso Total Tienda 2: $1,116,343,500.00
# Ingreso Total Tienda 3: $1,098,019,600.00
# Ingreso Total Tienda 4: $1,038,375,700.00

# %%
tiendas = {
    'tienda': ['tienda 1', 'tienda 2', 'tienda 3', 'tienda 4'],
    'ingresos': [ingresos_tienda1, ingresos_tienda2, ingresos_tienda3, ingresos_tienda4]
}
df_ingresostotal = pd.DataFrame(tiendas).set_index('tienda')
df_ingresostotal.plot(
    kind='barh',
    figsize=(12, 8),
    color='purple',
    legend=False,
    title='Ingresos Totales por Tiendas'
)
# Out:
# <Axes: title={'center': 'Ingresos Totales por Tiendas'}, ylabel='tienda'>

# %% [markdown]
# # 2. Ventas por categoría

# %%
tienda['Tienda'] = 'Tienda 1'
tienda2['Tienda'] = 'Tienda 2'
tienda3['Tienda'] = 'Tienda 3'
tienda4['Tienda'] = 'Tienda 4'

todas_las_tiendas = pd.concat([tienda, tienda2, tienda3, tienda4])
df_popularidad = todas_las_tiendas.groupby(['Categoría del Producto', 'Tienda']).size().unstack().fillna(0)
df_popularidad['Total Global'] = df_popularidad.sum(axis=1)
df_top_popular = df_popularidad.sort_values('Total Global', ascending=True).tail(5)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
sns.heatmap(df_top_popular.drop(columns='Total Global'),
            annot=True,
            fmt=".0f",
            cmap='Blues',
            linewidths=.5)

plt.title('Intensidad de Ventas por Categoría y Tienda')
plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# # 5. Envío promedio por tienda
